# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

# %%
im = Image.open("/home/yuzhong/data1/image_classifier_data/test/no_target/YNNR044X-NZ0070-20200516-00467.jpg")
# im = Image.open("/home/yuzhong/data1/image_classifier_data/test/human/JXNR003X-HH0002-20220308-00004.jpg")
plt.imshow(im)
plt.axis('off')  # Hide axes
plt.show()
