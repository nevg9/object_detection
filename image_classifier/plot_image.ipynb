# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

# %%
im = Image.open("/home/yuzhong/data1/image_classifier_data/test/animal/HBNR013X-NH0004-20191206-00544.jpg")
# im = Image.open("/home/yuzhong/data1/image_classifier_data/test/human/JXNR003X-HH0002-20220308-00004.jpg")
plt.imshow(im)
plt.axis('off')  # Hide axes
plt.show()
