# %%
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

# %%
im = Image.open("/home/yuzhong/data1/image_classifier_data/test/human/HBNR009X-BH0006-20210729-00170.jpg")
# im = Image.open("/home/yuzhong/data1/image_classifier_data/test/human/JXNR003X-HH0002-20220308-00004.jpg")
plt.imshow(im)
plt.axis('off')  # Hide axes
plt.show()
